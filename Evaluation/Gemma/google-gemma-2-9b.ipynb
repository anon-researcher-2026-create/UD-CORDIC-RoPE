# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# # =========================================================
# # 0. MEMORY FAILSAFE & LIBRARY UPDATE
# # =========================================================
# # Run this once in a separate cell if you get an ImportError:
# # !pip install -U transformers accelerate datasets

# import torch
# import gc
# torch.cuda.empty_cache()
# gc.collect()

# # =========================================================
# # 1. IMPORTS & SETUP
# # =========================================================
# import math
# from transformers import AutoModelForCausalLM, AutoTokenizer
# from transformers.models.gemma2 import modeling_gemma2
# from datasets import load_dataset
# from tqdm import tqdm

# device = "cuda" if torch.cuda.is_available() else "cpu"
# print("Using device:", device)

# # =========================================================
# # 2. TOKEN INJECTION & MODEL LOADING (GEMMA 2)
# # =========================================================
# model_name = "google/gemma-2-9b"

# # 🚨 PASTE YOUR HUGGING FACE TOKEN HERE 🚨
# # Make sure you have accepted the Gemma-2 license on the Hugging Face website!
# MY_HF_TOKEN = "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"

# print(f"Loading tokenizer for {model_name}...")
# tokenizer = AutoTokenizer.from_pretrained(model_name, token=MY_HF_TOKEN)

# if tokenizer.pad_token is None:
#     tokenizer.pad_token = tokenizer.eos_token

# print("Loading Gemma-2 9B across TWO GPUs (OOM Optimized)...")
# model = AutoModelForCausalLM.from_pretrained(
#     model_name,
#     torch_dtype=torch.float16,
#     device_map="auto", # Splits the 18GB model across both GPUs
#     token=MY_HF_TOKEN,
#     use_safetensors=True
# )
# model.eval()
# print("Model loaded successfully.")

# # =========================================================
# # 3. DYNAMIC RoPE PATCH (BINARY VS CSD MATH)
# # =========================================================
# if not hasattr(modeling_gemma2, "_ORIG_ROPE"):
#     modeling_gemma2._ORIG_ROPE = modeling_gemma2.apply_rotary_pos_emb

# _ORIG = modeling_gemma2._ORIG_ROPE

# def rotate_half(x):
#     half = x.shape[-1] // 2
#     x1 = x[..., :half]
#     x2 = x[..., half:]
#     return torch.cat((-x2, x1), dim=-1)

# def cordic_rope(q, k, cos, sin, unsqueeze_dim=1, std_dev=0.01):
#     theta = torch.atan2(sin, cos)
#     noise = torch.randn_like(theta) * std_dev
#     theta_approx = theta + noise

#     c_approx = torch.cos(theta_approx).unsqueeze(unsqueeze_dim)
#     s_approx = torch.sin(theta_approx).unsqueeze(unsqueeze_dim)

#     q_embed = (q * c_approx) + (rotate_half(q) * s_approx)
#     k_embed = (k * c_approx) + (rotate_half(k) * s_approx)
#     return q_embed, k_embed

# # Global variable to hold ("mode_name", fractional_bits)
# CURRENT_MODE = "float"

# def patched_rope(q, k, cos, sin, *args, **kwargs):
#     if CURRENT_MODE == "float":
#         return _ORIG(q, k, cos, sin, *args, **kwargs)

#     mode_name, frac_bits = CURRENT_MODE
#     u_dim = kwargs.get("unsqueeze_dim", 1)

#     # Calculate exact error margins based on hardware architecture
#     if mode_name == "binary":
#         # Standard Binary has a wider worst-case error bound
#         max_error = 1.216 * (2 ** -frac_bits)
#     elif mode_name == "csd":
#         # CSD optimization yields a tighter worst-case error bound
#         max_error = 1.024 * (2 ** -frac_bits)

#     # Convert max error to a 3-sigma standard deviation for Gaussian noise
#     std_dev = max_error / 3

#     return cordic_rope(q, k, cos, sin, unsqueeze_dim=u_dim, std_dev=std_dev)

# modeling_gemma2.apply_rotary_pos_emb = patched_rope

# # =========================================================
# # 4. DATASET
# # =========================================================
# print("Loading Wikitext-2 dataset...")
# dataset = load_dataset("wikitext", "wikitext-2-raw-v1", split="test")

# # =========================================================
# # 5. CONTINUOUS CONTEXT EVALUATOR
# # =========================================================
# def compute_perplexity_continuous(model, tokenizer, dataset, desc):
#     full_text = "\n\n".join([sample["text"] for sample in dataset if len(sample["text"].strip()) > 0])
#     encodings = tokenizer(full_text, return_tensors="pt")
#     seq_len = encodings.input_ids.size(1)
    
#     # REDUCED CONTEXT WINDOW TO PREVENT VRAM OOM CRASH
#     max_length = 1024 
#     nlls = []
    
#     for i in tqdm(range(0, seq_len, max_length), desc=f"Evaluating {desc}"):
#         begin_loc = i
#         end_loc = min(i + max_length, seq_len)
#         trg_len = end_loc - i
        
#         # device_map="auto" usually puts the first layer on cuda:0
#         input_ids = encodings.input_ids[:, begin_loc:end_loc].to("cuda:0")
#         target_ids = input_ids.clone()
        
#         with torch.no_grad():
#             outputs = model(input_ids, labels=target_ids)
#             # Use .item() to immediately pull the float out of the GPU VRAM
#             neg_log_likelihood = outputs.loss.item() * trg_len
#             nlls.append(neg_log_likelihood)
            
#         # Free up memory aggressively between loops
#         del input_ids, target_ids, outputs
#         torch.cuda.empty_cache()
            
#     total_loss = sum(nlls) / seq_len
#     ppl = math.exp(total_loss)
    
#     return ppl

# # =========================================================
# # 6. RUN THE DOUBLE BIT-WIDTH SWEEP
# # =========================================================
# results_binary = {}
# results_csd = {}

# print("\n" + "="*60)
# print(" STARTING GEMMA-2 9B DOUBLE SWEEP: BINARY vs CSD (f=3 to 14)")
# print("="*60)
# print(f"Dataset Token length: ~338,535 tokens")

# # Baseline
# CURRENT_MODE = "float"
# print("\n[0/24] Running FP16 Baseline...")
# fp16_baseline = compute_perplexity_continuous(model, tokenizer, dataset, "[FP16 Baseline]")

# # ---------------------------------------------------------
# # Phase 1: Standard Binary Sweep
# # ---------------------------------------------------------
# loop_counter = 1
# for frac_bits in range(3, 15):
#     total_bits = 1 + 1 + frac_bits # 1 sign, 1 int, f frac
#     label = f"{total_bits}-bit (f={frac_bits})"
    
#     print(f"\n[{loop_counter}/24] Running Standard BINARY for {label}...")
#     CURRENT_MODE = ("binary", frac_bits)
#     results_binary[label] = compute_perplexity_continuous(model, tokenizer, dataset, f"[BIN {label}]")
#     loop_counter += 1

# # ---------------------------------------------------------
# # Phase 2: CSD Sweep
# # ---------------------------------------------------------
# for frac_bits in range(3, 15):
#     total_bits = 1 + 1 + frac_bits
#     label = f"{total_bits}-bit (f={frac_bits})"
    
#     print(f"\n[{loop_counter}/24] Running CSD Optimized for {label}...")
#     CURRENT_MODE = ("csd", frac_bits)
#     results_csd[label] = compute_perplexity_continuous(model, tokenizer, dataset, f"[CSD {label}]")
#     loop_counter += 1

# # Restore original implementation
# modeling_gemma2.apply_rotary_pos_emb = _ORIG

# # =========================================================
# # 7. FINAL IEEE-READY TABLE PRINTER
# # =========================================================
# print("\n\n" + "="*60)
# print(" FINAL GEMMA-2 9B SWEEP RESULTS: BINARY vs CSD")
# print("="*60)
# print(f"FP16 Baseline (Control) : {fp16_baseline:.4f}")
# print("-" * 60)
# print(f"{'Bit-Width':<18} | {'Binary Perplexity':<18} | {'CSD Perplexity':<18}")
# print("-" * 60)

# for frac_bits in range(3, 15):
#     total_bits = 1 + 1 + frac_bits
#     label = f"{total_bits}-bit (f={frac_bits})"
#     bin_val = results_binary[label]
#     csd_val = results_csd[label]
#     print(f"{label:<18} | {bin_val:<18.4f} | {csd_val:<18.4f}")

# print("="*60)

# %%
# =========================================================
# 0. MEMORY FAILSAFE
# =========================================================
import torch
import gc
torch.cuda.empty_cache()
gc.collect()

# =========================================================
# 1. IMPORTS & SETUP
# =========================================================
import math
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers.models.gemma2 import modeling_gemma2
from datasets import load_dataset
from tqdm import tqdm

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

# =========================================================
# 2. TOKEN INJECTION & MODEL LOADING
# =========================================================
model_name = "google/gemma-2-9b"

# 🚨 PASTE YOUR HUGGING FACE TOKEN HERE 🚨
MY_HF_TOKEN = "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"

print(f"Loading tokenizer for {model_name}...")
tokenizer = AutoTokenizer.from_pretrained(model_name, token=MY_HF_TOKEN)

print("Loading Gemma-2 9B across TWO GPUs (OOM Optimized)...")
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto", 
    token=MY_HF_TOKEN,
    use_safetensors=True
)
model.eval()
print("Model loaded successfully.")

# =========================================================
# 3. DYNAMIC RoPE PATCH (BINARY VS CSD MATH)
# =========================================================
if not hasattr(modeling_gemma2, "_ORIG_ROPE"):
    modeling_gemma2._ORIG_ROPE = modeling_gemma2.apply_rotary_pos_emb

_ORIG = modeling_gemma2._ORIG_ROPE

def rotate_half(x):
    half = x.shape[-1] // 2
    x1 = x[..., :half]
    x2 = x[..., half:]
    return torch.cat((-x2, x1), dim=-1)

def cordic_rope(q, k, cos, sin, unsqueeze_dim=1, std_dev=0.01):
    theta = torch.atan2(sin, cos)
    noise = torch.randn_like(theta) * std_dev
    theta_approx = theta + noise

    c_approx = torch.cos(theta_approx).unsqueeze(unsqueeze_dim)
    s_approx = torch.sin(theta_approx).unsqueeze(unsqueeze_dim)

    q_embed = (q * c_approx) + (rotate_half(q) * s_approx)
    k_embed = (k * c_approx) + (rotate_half(k) * s_approx)
    return q_embed, k_embed

CURRENT_MODE = "float"

def patched_rope(q, k, cos, sin, *args, **kwargs):
    if CURRENT_MODE == "float":
        return _ORIG(q, k, cos, sin, *args, **kwargs)

    mode_name, frac_bits = CURRENT_MODE
    u_dim = kwargs.get("unsqueeze_dim", 1)

    if mode_name == "binary":
        max_error = 1.216 * (2 ** -frac_bits)
    elif mode_name == "csd":
        max_error = 1.024 * (2 ** -frac_bits)

    std_dev = max_error / 3
    return cordic_rope(q, k, cos, sin, unsqueeze_dim=u_dim, std_dev=std_dev)

modeling_gemma2.apply_rotary_pos_emb = patched_rope

# =========================================================
# 4. DATASET
# =========================================================
print("Loading Wikitext-2 dataset...")
dataset = load_dataset("wikitext", "wikitext-2-raw-v1", split="test")

# =========================================================
# 5. CONTINUOUS CONTEXT EVALUATOR (WITH BOS FIX & STRIDE)
# =========================================================
def compute_perplexity_continuous(model, tokenizer, dataset, desc):
    # Join text and encode WITHOUT special tokens (we will add BOS manually)
    full_text = "\n\n".join([sample["text"] for sample in dataset if len(sample["text"].strip()) > 0])
    encodings = tokenizer(full_text, return_tensors="pt", add_special_tokens=False)
    seq_len = encodings.input_ids.size(1)
    
    max_length = 1024 
    stride = 512 # Overlapping sliding window
    
    nlls = []
    prev_end_loc = 0
    
    for begin_loc in tqdm(range(0, seq_len, stride), desc=f"Evaluating {desc}"):
        end_loc = min(begin_loc + max_length, seq_len)
        trg_len = end_loc - prev_end_loc 
        
        input_ids = encodings.input_ids[:, begin_loc:end_loc].to("cuda:0")
        
        # 🚨 THE GEMMA FIX: Force BOS token at the start of the window
        input_ids[:, 0] = 2 
        
        target_ids = input_ids.clone()
        # 🚨 THE MASKING FIX: Don't calculate loss on the context overlap
        target_ids[:, :-trg_len] = -100 
        
        with torch.no_grad():
            outputs = model(input_ids, labels=target_ids)
            # Multiply by trg_len to weight the average correctly later
            neg_log_likelihood = outputs.loss * trg_len
            nlls.append(neg_log_likelihood.item())
            
        del input_ids, target_ids, outputs
        torch.cuda.empty_cache()
        
        prev_end_loc = end_loc
        if end_loc == seq_len:
            break
            
    total_loss = sum(nlls) / seq_len
    ppl = math.exp(total_loss)
    
    return ppl

# =========================================================
# 6. RUN THE DOUBLE BIT-WIDTH SWEEP
# =========================================================
results_binary = {}
results_csd = {}

print("\n" + "="*60)
print(" STARTING GEMMA-2 9B DOUBLE SWEEP: BINARY vs CSD (f=3 to 14)")
print("="*60)

CURRENT_MODE = "float"
print("\n[0/24] Running FP16 Baseline...")
fp16_baseline = compute_perplexity_continuous(model, tokenizer, dataset, "[FP16 Baseline]")

loop_counter = 1
for frac_bits in range(3, 15):
    total_bits = 1 + 1 + frac_bits
    label = f"{total_bits}-bit (f={frac_bits})"
    print(f"\n[{loop_counter}/24] Running Standard BINARY for {label}...")
    CURRENT_MODE = ("binary", frac_bits)
    results_binary[label] = compute_perplexity_continuous(model, tokenizer, dataset, f"[BIN {label}]")
    loop_counter += 1

for frac_bits in range(3, 15):
    total_bits = 1 + 1 + frac_bits
    label = f"{total_bits}-bit (f={frac_bits})"
    print(f"\n[{loop_counter}/24] Running CSD Optimized for {label}...")
    CURRENT_MODE = ("csd", frac_bits)
    results_csd[label] = compute_perplexity_continuous(model, tokenizer, dataset, f"[CSD {label}]")
    loop_counter += 1

modeling_gemma2.apply_rotary_pos_emb = _ORIG

# =========================================================
# 7. FINAL IEEE-READY TABLE PRINTER
# =========================================================
print("\n\n" + "="*60)
print(" FINAL GEMMA-2 9B SWEEP RESULTS: BINARY vs CSD")
print("="*60)
print(f"FP16 Baseline (Control) : {fp16_baseline:.4f}")
print("-" * 60)
print(f"{'Bit-Width':<18} | {'Binary Perplexity':<18} | {'CSD Perplexity':<18}")
print("-" * 60)

for frac_bits in range(3, 15):
    total_bits = 1 + 1 + frac_bits
    label = f"{total_bits}-bit (f={frac_bits})"
    bin_val = results_binary[label]
    csd_val = results_csd[label]
    print(f"{label:<18} | {bin_val:<18.4f} | {csd_val:<18.4f}")

print("="*60)
# Out:
# Using device: cuda
# Loading tokenizer for google/gemma-2-9b...
# config.json:   0%|          | 0.00/856 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading Gemma-2 9B across TWO GPUs (OOM Optimized)...
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/464 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# Model loaded successfully.
# Loading Wikitext-2 dataset...
# README.md: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# wikitext-2-raw-v1/test-00000-of-00001.pa(…):   0%|          | 0.00/733k [00:00<?, ?B/s]
# wikitext-2-raw-v1/train-00000-of-00001.p(…):   0%|          | 0.00/6.36M [00:00<?, ?B/s]
# wikitext-2-raw-v1/validation-00000-of-00(…):   0%|          | 0.00/657k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/4358 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/36718 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3760 [00:00<?, ? examples/s]
# ============================================================
#  STARTING GEMMA-2 9B DOUBLE SWEEP: BINARY vs CSD (f=3 to 14)
# ============================================================
#
# [0/24] Running FP16 Baseline...
# Evaluating [FP16 Baseline]:   0%|          | 0/565 [00:00<?, ?it/s]
# Evaluating [FP16 Baseline]:   0%|          | 1/565 [00:02<21:49,  2.32s/it]
# Evaluating [FP16 Baseline]:   0%|          | 2/565 [00:03<16:06,  1.72s/it]
# Evaluating [FP16 Baseline]:   1%|          | 3/565 [00:04<14:21,  1.53s/it]
# Evaluating [FP16 Baseline]:   1%|          | 4/565 [00:06<13:31,  1.45s/it]
# Evaluating [FP16 Baseline]:   1%|          | 5/565 [00:07<13:02,  1.40s/it]
# Evaluating [FP16 Baseline]:   1%|          | 6/565 [00:08<12:46,  1.37s/it]
# Evaluating [FP16 Baseline]:   1%|          | 7/565 [00:10<12:36,  1.36s/it]
# Evaluating [FP16 Baseline]:   1%|▏         | 8/565 [00:11<12:30,  1.35s/it]
# Evaluating [FP16 Baseline]:   2%|▏         | 9/565 [00:12<12:24,  1.34s/it]
# Evaluating [FP16 Baseline]:   2%|▏         | 10/565 [00:14<12:22,  1.34s/it]
# Evaluating [FP16 Baseline]:   2%|▏         | 11/565 [00:15<12:19,  1.34s/it]
# Evaluating [FP16 Baseline]:   2%|▏         | 12/565 [00:16<12:19,  1.34s/it]
# Evaluating [FP16 Baseline]:   2%|▏         | 13/565 [00:18<12:18,  1.34s/it]
# Evaluating [FP16 Baseline]:   2%|▏         | 14/565 [00:19<12:17,  1.34s/it]
# Evaluating [FP16 Baseline]:   3%|▎         | 15/565 [00:20<12:15,  1.34s/it]
# Evaluating [FP16 Baseline]:   3%|▎         | 16/565 [00:22<12:13,  1.34s/it]
# Evaluating [FP16 Baseline]:   3%|▎         | 17/565 [00:23<12:11,  1.33s/it]
# Evaluating [FP16 Baseline]:   3%|▎         | 18/565 [00:24<12:10,  1.33s/it]
# Evaluating [FP16 Baseline]:   3%|▎         | 19/565 [00:26<12:09,  1.34s/it]
# Evaluating [FP16 Baseline]:   4%|▎         | 20/565 [00:27<12:08,  1.34s/it]
# Evaluating [FP16 Baseline]:   4%|▎         | 21/565 [00:28<12:09,  1.34s/it]
# Evaluating [FP16 Baseline]:   4%|▍         | 22/565 [00:30<12:09,  1.34s/it]
# Evaluating [FP16 Baseline]:   4%|▍         | 23/565 [00:31<12:10,  1.35s/it]
# Evaluating [FP16 Baseline]:   4%|▍         | 24/565 [00:32<12:10,  1.35s/it]
# Evaluating [FP16 Baseline]:   4%|▍         | 25/565 [00:34<12:10,  1.35s/it]
# Evaluating [FP16 Baseline]:   5%|▍         | 26/565 [00:35<12:10,  1.36s/it]
# Evaluating [FP16 Baseline]:   5%|▍         | 27/565 [00:37<12:11,  1.36s/it]
# Evaluating [FP16 Baseline]:   5%|▍         | 28/565 [00:38<12:10,  1.36s/it]
# Evaluating [FP16 Baseline]:   5%|▌         | 29/565 [00:39<12:11,  1.37s/it]
# Evaluating [FP16 Baseline]:   5%|▌         | 30/565 [00:41<12:11,  1.37s/it]
# Evaluating [FP16 Baseline]:   5%|▌         | 31/565 [00:42<12:11,  1.37s/it]
# Evaluating [FP16 Baseline]:   6%|▌         | 32/565 [00:43<12:11,  1.37s/it]
# Evaluating [FP16 Baseline]:   6%|▌         | 33/565 [00:45<12:12,  1.38s/it]
# Evaluating [FP16 Baseline]:   6%|▌         | 34/565 [00:46<12:12,  1.38s/it]
# Evaluating [FP16 Baseline]:   6%|▌         | 35/565 [00:48<12:10,  1.38s/it]
# Evaluating [FP16 Baseline]:   6%|▋         | 36/565 [00:49<12:09,  1.38s/it]
# Evaluating [FP16 Baseline]:   7%|▋         | 37/565 [00:50<12:08,  1.38s/it]
# Evaluating [FP16 Baseline]:   7%|▋         | 38/565 [00:52<12:07,  1.38s/it]
# Evaluating [FP16 Baseline]:   7%|▋         | 39/565 [00:53<12:08,  1.38s/it]
# Evaluating [FP16 Baseline]:   7%|▋         | 40/565 [00:55<12:10,  1.39s/it]
# Evaluating [FP16 Baseline]:   7%|▋         | 41/565 [00:56<12:08,  1.39s/it]
# Evaluating [FP16 Baseline]:   7%|▋         | 42/565 [00:57<12:08,  1.39s/it]
# Evaluating [FP16 Baseline]:   8%|▊         | 43/565 [00:59<12:09,  1.40s/it]
# Evaluating [FP16 Baseline]:   8%|▊         | 44/565 [01:00<12:07,  1.40s/it]
# Evaluating [FP16 Baseline]:   8%|▊         | 45/565 [01:02<12:07,  1.40s/it]
# Evaluating [FP16 Baseline]:   8%|▊         | 46/565 [01:03<12:06,  1.40s/it]
# Evaluating [FP16 Baseline]:   8%|▊         | 47/565 [01:04<12:07,  1.40s/it]
# Evaluating [FP16 Baseline]:   8%|▊         | 48/565 [01:06<12:07,  1.41s/it]
# Evaluating [FP16 Baseline]:   9%|▊         | 49/565 [01:07<12:06,  1.41s/it]
# Evaluating [FP16 Baseline]:   9%|▉         | 50/565 [01:09<12:07,  1.41s/it]
# Evaluating [FP16 Baseline]:   9%|▉         | 51/565 [01:10<12:06,  1.41s/it]
# Evaluating [FP16 Baseline]:   9%|▉         | 52/565 [01:11<12:08,  1.42s/it]
# Evaluating [FP16 Baseline]:   9%|▉         | 53/565 [01:13<12:07,  1.42s/it]
# Evaluating [FP16 Baseline]:  10%|▉         | 54/565 [01:14<12:07,  1.42s/it]
# Evaluating [FP16 Baseline]:  10%|▉         | 55/565 [01:16<12:06,  1.43s/it]
# Evaluating [FP16 Baseline]:  10%|▉         | 56/565 [01:17<12:08,  1.43s/it]
# Evaluating [FP16 Baseline]:  10%|█         | 57/565 [01:19<12:08,  1.43s/it]
# Evaluating [FP16 Baseline]:  10%|█         | 58/565 [01:20<12:08,  1.44s/it]
# Evaluating [FP16 Baseline]:  10%|█         | 59/565 [01:21<12:10,  1.44s/it]
# Evaluating [FP16 Baseline]:  11%|█         | 60/565 [01:23<12:10,  1.45s/it]
# Evaluating [FP16 Baseline]:  11%|█         | 61/565 [01:24<12:10,  1.45s/it]
# Evaluating [FP16 Baseline]:  11%|█         | 62/565 [01:26<12:11,  1.45s/it]
# Evaluating [FP16 Baseline]:  11%|█         | 63/565 [01:27<12:12,  1.46s/it]
# Evaluating [FP16 Baseline]:  11%|█▏        | 64/565 [01:29<12:12,  1.46s/it]
# Evaluating [FP16 Baseline]:  12%|█▏        |
# Evaluating [FP16 Baseline]:  80%|███████▉  | 451/565 [11:29<02:57,  1.56s/it]
# Evaluating [FP16 Baseline]:  80%|████████  | 452/565 [11:31<02:56,  1.56s/it]
# Evaluating [FP16 Baseline]:  80%|████████  | 453/565 [11:32<02:54,  1.56s/it]
# Evaluating [FP16 Baseline]:  80%|████████  | 454/565 [11:34<02:52,  1.56s/it]
# Evaluating [FP16 Baseline]:  81%|████████  | 455/565 [11:36<02:51,  1.56s/it]
# Evaluating [FP16 Baseline]:  81%|████████  | 456/565 [11:37<02:49,  1.56s/it]
# Evaluating [FP16 Baseline]:  81%|████████  | 457/565 [11:39<02:48,  1.56s/it]
# Evaluating [FP16 Baseline]:  81%|████████  | 458/565 [11:40<02:46,  1.56s/it]
# Evaluating [FP16 Baseline]:  81%|████████  | 459/565 [11:42<02:44,  1.56s/it]
# Evaluating [FP16 Baseline]:  81%|████████▏ | 460/565 [11:43<02:43,  1.56s/it]
# Evaluating [FP16 Baseline]:  82%|████████▏ | 461/565 [11:45<02:42,  1.56s/it]
# Evaluating [FP16 Baseline]:  82%|████████▏ | 462/565 [11:46<02:40,  1.56s/it]
# Evaluating [FP16 Baseline]:  82%|████████▏ | 463/565 [11:48<02:38,  1.56s/it]
# Evaluating [FP16 Baseline]:  82%|████████▏ | 464/565 [11:50<02:37,  1.56s/it]
# Evaluating [FP16 Baseline]:  82%|████████▏ | 465/565 [11:51<02:35,  1.56s/it]
# Evaluating [FP16 Baseline]:  82%|████████▏ | 466/565 [11:53<02:34,  1.56s/it]
# Evaluating [FP16 Baseline]:  83%|████████▎ | 467/565 [11:54<02:33,  1.56s/it]
# Evaluating [FP16 Baseline]:  83%|████████▎ | 468/565 [11:56<02:31,  1.56s/it]
# Evaluating [FP16 Baseline]:  83%|████████▎ | 469/565 [11:57<02:30,  1.56s/it]
# Evaluating [FP16 Baseline]:  83%|████████▎ | 470/565 [11:59<02:27,  1.56s/it]
# Evaluating [FP16 Baseline]:  83%|████████▎ | 471/565 [12:00<02:26,  1.56s/it]
# Evaluating [FP16 Baseline]:  84%|████████▎ | 472/565 [12:02<02:25,  1.56s/it]
# Evaluating [FP16 Baseline]:  84%|████████▎ | 473/565 [12:04<02:23,  1.56s/it]
# Evaluating [FP16 Baseline]:  84%|████████▍ | 474/565 [12:05<02:21,  1.56s/it]
# Evaluating [FP16 Baseline]:  84%|████████▍ | 475/565 [12:07<02:20,  1.56s/it]
# Evaluating [FP16 Baseline]:  84%|████████▍ | 476/565 [12:08<02:19,  1.56s/it]
# Evaluating [FP16 Baseline]:  84%|████████▍ | 477/565 [12:10<02:17,  1.56s/it]
# Evaluating [FP16 Baseline]:  85%|████████▍ | 478/565 [12:11<02:15,  1.56s/it]
# Evaluating [FP16 Baseline]:  85%|████████▍ | 479/565 [12:13<02:14,  1.56s/it]
# Evaluating [FP16 Baseline]:  85%|████████▍ | 480/565 [12:15<02:12,  1.56s/it]
# Evaluating [FP16 Baseline]:  85%|████████▌ | 481/565 [12:16<02:11,  1.56s/it]
# Evaluating [FP16 Baseline]:  85%|████████▌ | 482/565 [12:18<02:09,  1.55s/it]
# Evaluating [FP16 Baseline]:  85%|████████▌ | 483/565 [12:19<02:07,  1.56s/it]
# Evaluating [FP16 Baseline]:  86%|████████▌ | 484/565 [12:21<02:06,  1.56s/it]
# Evaluating [FP16 Baseline]:  86%|████████▌ | 485/565 [12:22<02:04,  1.56s/it]
# Evaluating [FP16 Baseline]:  86%|████████▌ | 486/565 [12:24<02:03,  1.56s/it]
# Evaluating [FP16 Baseline]:  86%|████████▌ | 487/565 [12:25<02:01,  1.56s/it]
# Evaluating [FP16 Baseline]:  86%|████████▋ | 488/565 [12:27<02:00,  1.56s/it]
# Evaluating [FP16 Baseline]:  87%|████████▋ | 489/565 [12:29<01:58,  1.56s/it]
# Evaluating [FP16 Baseline]:  87%|████████▋ | 490/565 [12:30<01:56,  1.56s/it]
# Evaluating [FP16 Baseline]:  87%|████████▋ | 491/565 [12:32<01:55,  1.56s/it]
# Evaluating [FP16 Baseline]:  87%|████████▋ | 492/565 [12:33<01:53,  1.56s/it]
# Evaluating [FP16 Baseline]:  87%|████████▋ | 493/565 [12:35<01:52,  1.56s/it]
# Evaluating [FP16 Baseline]:  87%|████████▋ | 494/565 [12:36<01:50,  1.56s/it]
# Evaluating [FP16 Baseline]:  88%|████████▊ | 495/565 [12:38<01:49,  1.56s/it]
# Evaluating [FP16 Baseline]:  88%|████████▊ | 496/565 [12:39<01:47,  1.56s/it]
# Evaluating [FP16 Baseline]:  88%|████████▊ | 497/565 [12:41<01:45,  1.56s/it]
# Evaluating [FP16 Baseline]:  88%|████████▊ | 498/565 [12:43<01:44,  1.56s/it]
# Evaluating [FP16 Baseline]:  88%|████████▊ | 499/565 [12:44<01:43,  1.56s/it]
# Evaluating [FP16 Baseline]:  88%|████████▊ | 500/565 [12:46<01:41,  1.56s/it]
# Evaluating [FP16 Baseline]:  89%|████████▊ | 501/565 [12:47<01:39,  1.56s/it]
# Evaluating [FP16 Baseline]:  89%|████████▉ | 502/565 [12:49<01:38,  1.56s/it]
# Evaluating [FP16 Baseline]:  89%|████████▉ | 503/565 [12:50<01:36,  1.56s/it]
# Evaluating [FP16 Baseline]:  89%|████████▉ | 504/565 [12:52<01:34,  1.55s/it]
# Evaluating [FP16 Baseline]:  89%|████████▉ | 505/565 [12:53<01:33,  1.55s/it]
# Evaluating [FP16 Baseline]:  90%|████████▉ | 506/565 [12:55<01:31,  1.56s/it]
# Evaluating [FP16 Baseline]:  90%|████████▉ | 507/565 [12:57<01:29,  1.55s/it]
# Evaluating [FP16 Baseline]:  90%|████████▉ | 508/565 [12:58<01:28,  1.55s/it]
# Evaluating [FP16 Baseline]:  90%|█████████ | 509/565 [13:00<01:27,  1.55s/it]
# Evaluating [FP16 Baseline]:  90%|█████████ | 510/565 [13:01<01:25,  1.55s/it]
# Evaluating [FP16 Baseline]:  90%|█████████ | 511/565 [13:03<01:23,  1.55s/it]
# Evaluating [FP16 Baseline]:  91%|█████████ | 512/565 [13:04<01:22,  1.56s/it]
# Evaluating [FP16 Baseline]:  91%|█████████ | 513/565 [13:06<01:21,  1.56s/it]
# Evaluating [FP16 Baseline]:  91%|█████████ | 514/565 [13:07<01:19,  1.56s/it]
# Evaluating [FP16 Baseline]:  91%|█████████ | 515/565 [13:09<01:17,  1.56s/it]
# Evaluating [FP16 Baseline]:  91%|█████████▏| 516/565 [13:11<01:16,  1.56s/it]
# Evaluating [FP16 Baseline]:  92%|█████████▏| 517/565 [13:12<01:14,  1.56s/it]
# Evaluating [FP16 Baseline]:  92%|█████████▏| 518/565 [13:14<01:13,  1.56s/it]
# Evaluating [FP16 Baseline]:  92%|█████████▏| 519/565 [13:15<01:11,  1.55s/it]
# Evaluating [FP16 Baseline]:  92%|█████████▏| 520/565 [13:17<01:10,  1.56s/it]
# Evaluating [FP16 Baseline]:  92%|█████████▏| 521/565 [13:18<01:08,  1.56s/it]
# Evaluating [FP16 Baseline]:  92%|█████████▏| 522/565 [13:20<01:06,  1.56s/it]
# Evaluating [FP16 Baseline]:  93%|█████████▎| 523/565 [13:22<01:05,  1.56s/it]
# Evaluating [FP16 Baseline]:  93%|█████████▎| 524/565 [13:23<01:04,  1.56s/it]
# Evaluating [FP16 Baseline]:  93%|█████████▎| 525/565 [13:25<01:02,  1.56s/it]
# Evaluating [FP16 Baseline]:  93%|█████████▎| 526/565 [13:26<01:00,  1.56s/it]
# Evaluating [FP16 Baseline]:  93%|█████████▎| 527/565 [13:28<00:59,  1.56s/it]
# Evaluating [FP16 Baseline]:  93%|█████████▎| 528/565 [13:29<00:57,  1.56s/it]
# Evaluating [FP16 Baseline]:  94%|█████████▎| 529/565 [13:31<00:56,  1.56s/it]
# Evaluating [FP16 Baseline]:  94%|█████████▍| 530/565 [13:32<00:54,  1.56s/it]
# Evaluating [FP16 Baseline]:  94%|█████████▍| 531/565 [13:34<00:53,  1.56s/it]
# Evaluating [FP16 Baseline]:  94%|█████████▍| 532/565 [13:36<00:51,  1.57s/it]
# Evaluating [FP16 Baseline]:  94%|█████████▍| 533/565 [13:37<00:50,  1.56s/it]
# Evaluating [FP16 Baseline]:  95%|█████████▍| 534/565 [13:39<00:48,  1.56s/it]
# Evaluating [FP16 Baseline]:  95%|█████████▍| 535/565 [13:40<00:46,  1.56s/it]
# Evaluating [FP16 Baseline]:  95%|█████████▍| 536/565 [13:42<00:45,  1.57s/it]
# Evaluating [FP16 Baseline]:  95%|█████████▌| 537/565 [13:43<00:43,  1.57s/it]
# Evaluating [FP16 Baseline]:  95%|█████████▌| 538/565 [13:45<00:42,  1.56s/it]
# Evaluating [FP16 Baseline]:  95%|█████████▌| 539/565 [13:47<00:40,  1.56s/it]
# Evaluating [FP16 Baseline]:  96%|█████████▌| 540/565 [13:48<00:39,  1.56s/it]
# Evaluating [FP16 Baseline]:  96%|█████████▌| 541/565 [13:50<00:37,  1.56s/it]
# Evaluating [FP16 Baseline]:  96%|█████████▌| 542/565 [13:51<00:35,  1.56s/it]
# Evaluating [FP16 Baseline]:  96%|█████████▌| 543/565 [13:53<00:34,  1.56s/it]
# Evaluating [FP16 Baseline]:  96%|█████████▋| 544/565 [13:54<00:32,  1.56s/it]
# Evaluating [FP16 Baseline]:  96%|█████████▋| 545/565 [13:56<00:31,  1.56s/it]
# Evaluating [FP16 Baseline]:  97%|█████████▋| 546/565 [13:57<00:29,  1.56s/it]
# Evaluating [FP16 Baseline]:  97%|█████████▋| 547/565 [13:59<00:28,  1.56s/it]
# Evaluating [FP16 Baseline]:  97%|█████████▋| 548/565 [14:01<00:26,  1.56s/it]
# Evaluating [FP16 Baseline]:  97%|█████████▋| 549/565 [14:02<00:24,  1.56s/it]
# Evaluating [FP16 Baseline]:  97%|█████████▋| 550/565 [14:04<00:23,  1.55s/it]
# Evaluating [FP16 Baseline]:  98%|█████████▊| 551/565 [14:05<00:21,  1.56s/it]
# Evaluating [FP16 Baseline]:  98%|█████████▊| 552/565 [14:07<00:20,  1.56s/it]
# Evaluating [FP16 Baseline]:  98%|█████████▊| 553/565 [14:08<00:18,  1.56s/it]
# Evaluating [FP16 Baseline]:  98%|█████████▊| 554/565 [14:10<00:17,  1.56s/it]
# Evaluating [FP16 Baseline]:  98%|█████████▊| 555/565 [14:11<00:15,  1.56s/it]
# Evaluating [FP16 Baseline]:  98%|█████████▊| 556/565 [14:13<00:14,  1.56s/it]
# Evaluating [FP16 Baseline]:  99%|█████████▊| 557/565 [14:15<00:12,  1.56s/it]
# Evaluating [FP16 Baseline]:  99%|█████████▉| 558/565 [14:16<00:10,  1.55s/it]
# Evaluating [FP16 Baseline]:  99%|█████████▉| 559/565 [14:18<00:09,  1.56s/it]
# Evaluating [FP16 Baseline]:  99%|█████████▉| 560/565 [14:19<00:07,  1.56s/it]
# Evaluating [FP16 Baseline]:  99%|█████████▉| 561/565 [14:21<00:06,  1.56s/it]
# Evaluating [FP16 Baseline]:  99%|█████████▉| 562/565 [14:22<00:04,  1.56s/it]
# Evaluating [FP16 Baseline]: 100%|█████████▉| 563/565 [14:25<00:03,  1.54s/it]
# [1/24] Running Standard BINARY for 5-bit (f=3)...
# Evaluating [BIN 5-bit (f=3)]:   0%|          | 0/565 [00:00<?, ?it/s]
# Evaluating [BIN 5-bit (f=3)]:   0%|          | 1/565 [00:01<14:54,  1.59s/it]
# Evaluating [BIN 5-bit (f=3)]:   0%|          | 2/565 [00:03<14:42,  1.57s/it]
# Evaluating [BIN 5-bit (f=3)]:   1%|          | 3/565 [00:04<14:37,  1.56s/it]
# Evaluating [BIN 5-bit (f=3)]:   1%|          | 4/565 [00:06<14:34,  1.56s/it]
# Evaluating [BIN 5-bit (f=3)]:   1%|          | 5/565 [00:07<14:33,  1.56s/it]
# Evaluating [BIN 5-bit (f=3)]:   1%|          | 6/565 [00:09<14:32,  1.56s/it]
# Evaluating [BIN 5-bit (f=3)]:   1%|          | 7/565 [00:10<14:33,  1.57s/it]
# Evaluating [BIN 5-bit (f=3)]:   1%|▏         | 8/565 [00:12<14:33,  1.57s/it]
# Evaluating [BIN 5-bit (f=3)]:   2%|▏         | 9/565 [00:14<14:32,  1.57s/it]
# Evaluating [BIN 5-bit (f=3)]:   2%|▏         | 10/565 [00:15<14:28,  1.57s/it]
# Evaluating [BIN 5-bit (f=3)]:   2%|▏         |
  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  91%|█████████ | 512/565 [13:18<01:22,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  91%|█████████ | 513/565 [13:20<01:20,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  91%|█████████ | 514/565 [13:21<01:19,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  91%|█████████ | 515/565 [13:23<01:17,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  91%|█████████▏| 516/565 [13:25<01:15,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  92%|█████████▏| 517/565 [13:26<01:14,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  92%|█████████▏| 518/565 [13:28<01:13,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  92%|█████████▏| 519/565 [13:29<01:11,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  92%|█████████▏| 520/565 [13:31<01:09,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  92%|█████████▏| 521/565 [13:32<01:08,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  92%|█████████▏| 522/565 [13:34<01:07,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  93%|█████████▎| 523/565 [13:36<01:05,  1.57s/it]
# Evaluating [CSD 16-bit (f=14)]:  93%|█████████▎| 524/565 [13:37<01:04,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  93%|█████████▎| 525/565 [13:39<01:02,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  93%|█████████▎| 526/565 [13:40<01:00,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  93%|█████████▎| 527/565 [13:42<00:59,  1.57s/it]
# Evaluating [CSD 16-bit (f=14)]:  93%|█████████▎| 528/565 [13:43<00:57,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  94%|█████████▎| 529/565 [13:45<00:56,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  94%|█████████▍| 530/565 [13:46<00:54,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  94%|█████████▍| 531/565 [13:48<00:53,  1.57s/it]
# Evaluating [CSD 16-bit (f=14)]:  94%|█████████▍| 532/565 [13:50<00:51,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  94%|█████████▍| 533/565 [13:51<00:49,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  95%|█████████▍| 534/565 [13:53<00:48,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  95%|█████████▍| 535/565 [13:54<00:46,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  95%|█████████▍| 536/565 [13:56<00:45,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  95%|█████████▌| 537/565 [13:57<00:43,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  95%|█████████▌| 538/565 [13:59<00:42,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  95%|█████████▌| 539/565 [14:01<00:40,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  96%|█████████▌| 540/565 [14:02<00:39,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  96%|█████████▌| 541/565 [14:04<00:37,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  96%|█████████▌| 542/565 [14:05<00:35,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  96%|█████████▌| 543/565 [14:07<00:34,  1.57s/it]
# Evaluating [CSD 16-bit (f=14)]:  96%|█████████▋| 544/565 [14:08<00:32,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  96%|█████████▋| 545/565 [14:10<00:31,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  97%|█████████▋| 546/565 [14:11<00:29,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  97%|█████████▋| 547/565 [14:13<00:28,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  97%|█████████▋| 548/565 [14:15<00:26,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  97%|█████████▋| 549/565 [14:16<00:24,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  97%|█████████▋| 550/565 [14:18<00:23,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  98%|█████████▊| 551/565 [14:19<00:21,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  98%|█████████▊| 552/565 [14:21<00:20,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  98%|█████████▊| 553/565 [14:22<00:18,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  98%|█████████▊| 554/565 [14:24<00:17,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  98%|█████████▊| 555/565 [14:25<00:15,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  98%|█████████▊| 556/565 [14:27<00:13,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  99%|█████████▊| 557/565 [14:29<00:12,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  99%|█████████▉| 558/565 [14:30<00:10,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  99%|█████████▉| 559/565 [14:32<00:09,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  99%|█████████▉| 560/565 [14:33<00:07,  1.56s/it]
# Evaluating [CSD 16-bit (f=14)]:  99%|█████████▉| 561/565 [14:35<00:06,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]:  99%|█████████▉| 562/565 [14:36<00:04,  1.55s/it]
# Evaluating [CSD 16-bit (f=14)]: 100%|█████████▉| 563/565 [14:39<00:03,  1.56s/it]
# ============================================================
#  FINAL GEMMA-2 9B SWEEP RESULTS: BINARY vs CSD
# ============================================================
# FP16 Baseline (Control) : 6.3882
# ------------------------------------------------------------
# Bit-Width          | Binary Perplexity  | CSD Perplexity
# ------------------------------------------------------------
# 5-bit (f=3)        | 6.4489             | 6.4306
# 6-bit (f=4)        | 6.4013             | 6.3982
# 7-bit (f=5)        | 6.3912             | 6.3911
# 8-bit (f=6)        | 6.3893             | 6.3889
# 9-bit (f=7)        | 6.3884             | 6.3882
# 10-bit (f=8)       | 6.3881             | 6.3882
# 11-bit (f=9)       | 6.3882             | 6.3881
# 12-bit (f=10)      | 6.3882             | 6.3881
# 13-bit (f=11)      | 6.3881             | 6.3882
# 14-bit (f=12)      | 6.3882             | 6.3881
# 15-bit (f=13)      | 6.3881             | 6.3882
# 16-bit (f=14)      | 6.3881             | 6.3881
# ============================================================
